# %% [markdown]
# - pd.read_html: returns a list of dataframes, one dataframe for each html table on the page

# %%
import requests
import pandas as pd
df_list = pd.read_html('https://www.x-rates.com/table/?from=USD&amount=1')
#df_list = pd.read_html("https://eresearch.fidelity.com/eresearch/goto/markets_sectors/landing.jhtml",flavor="bs4")
print(len(df_list))
# Out:
# 2

# %% [markdown]
# - web.DataReader
# - https://pandas-datareader.readthedocs.io/en/latest/readers/yahoo.html

# %%
from pandas_datareader import data as web
import yfinance as yf
import datetime
start=datetime.datetime(2023, 1, 1)
end=datetime.datetime.today()
df = web.DataReader('IBM', start, end)
df
# Out:
# [*********************100%***********************]  1 of 1 completed
#                                  Open        High         Low       Close  \
# Date
# 2023-01-03 00:00:00-05:00  141.100006  141.899994  140.479996  141.550003
# 2023-01-04 00:00:00-05:00  142.070007  143.619995  141.369995  142.600006
# 2023-01-05 00:00:00-05:00  142.440002  142.500000  140.009995  141.110001
# 2023-01-06 00:00:00-05:00  142.380005  144.250000  141.580002  143.699997
# 2023-01-09 00:00:00-05:00  144.080002  145.470001  143.399994  143.550003
# 2023-01-10 00:00:00-05:00  143.610001  144.850006  142.899994  144.800003
# 2023-01-11 00:00:00-05:00  145.000000  145.529999  143.449997  145.259995
# 2023-01-12 00:00:00-05:00  144.880005  146.660004  144.520004  145.550003
# 2023-01-13 00:00:00-05:00  144.059998  146.100006  144.009995  145.889999
#
#                             Adj Close   Volume
# Date
# 2023-01-03 00:00:00-05:00  141.550003  3338600
# 2023-01-04 00:00:00-05:00  142.600006  3869200
# ...

# %% [markdown]
# - yfinance
# - https://pypi.org/project/yfinance/

# %%
df_msft = yf.download('MSFT', start = '2023-01-01', end='2023-01-15')
df_msft
# Out:
# [*********************100%***********************]  1 of 1 completed
#                                  Open        High         Low       Close  \
# Date
# 2023-01-03 00:00:00-05:00  243.080002  245.750000  237.399994  239.580002
# 2023-01-04 00:00:00-05:00  232.279999  232.869995  225.960007  229.100006
# 2023-01-05 00:00:00-05:00  227.199997  227.550003  221.759995  222.309998
# 2023-01-06 00:00:00-05:00  223.000000  225.759995  219.350006  224.929993
# 2023-01-09 00:00:00-05:00  226.449997  231.240005  226.410004  227.119995
# 2023-01-10 00:00:00-05:00  227.759995  231.309998  227.330002  228.850006
# 2023-01-11 00:00:00-05:00  231.289993  235.949997  231.110001  235.770004
# 2023-01-12 00:00:00-05:00  235.259995  239.899994  233.559998  238.509995
# 2023-01-13 00:00:00-05:00  237.000000  239.369995  234.919998  239.229996
#
#                             Adj Close    Volume
# Date
# 2023-01-03 00:00:00-05:00  239.580002  25740000
# 2023-01-04 00:00:00-05:00  229.100006  50623400
# ...
